# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("data.csv")
df
# Out:
#     Country               Channel Name       Category Main Video Category  \
# 0        IN                   T-Series  Gaming & Apps               Music
# 1        US  ABCkidTV - Nursery Rhymes  Gaming & Apps           Education
# 2        IN                  SET India  Gaming & Apps               Shows
# 3        US                  PewDiePie  Gaming & Apps              Gaming
# 4        US                    MrBeast  Gaming & Apps       Entertainment
# ..      ...                        ...            ...                 ...
# 852     NaN               1theK (원더케이)          Music               Music
# 853      US                Post Malone  Gaming & Apps               Music
# 854      IN               Amit Bhadana            NaN       Entertainment
# 855      US              James Charles  Gaming & Apps       Entertainment
# 856      US                    Netflix           None       Entertainment
#
#                       username  followers     Main topic  \
# ...

# %%
data=df['followers'].astype('int64')
followers=pd.DataFrame(data)
followers.plot(kind='density')
plt.savefig('xyz.jpg',dpi=300)
plt.show()

# %%
followers_mean=np.mean(df['followers'])
followers_mean
# Out:
# 49529754.95915986

# %%
followers_median=np.median(df['followers'])
followers_median
# Out:
# 41300000.0

# %%
data=df['Avg. 1 Day'].dropna()
plt.boxplot(data)
plt.show()

# %%
df=df.dropna()
df
# Out:
#     Country               Channel Name       Category Main Video Category  \
# 0        IN                   T-Series  Gaming & Apps               Music
# 1        US  ABCkidTV - Nursery Rhymes  Gaming & Apps           Education
# 7        IN                   T-Series  Gaming & Apps               Music
# 8        US  ABCkidTV - Nursery Rhymes  Gaming & Apps           Education
# 15       IN          Zee Music Company          Music               Music
# ..      ...                        ...            ...                 ...
# 842      US              KatyPerryVEVO  Gaming & Apps               Music
# 845      BR           Marília Mendonça  Gaming & Apps               Music
# 847      CA              WatchMojo.com           None       Entertainment
# 849      US                Nicki Minaj      LifeStyle               Music
# 856      US                    Netflix           None       Entertainment
#
#                       username  followers              Main topic  \
# ...

# %%
plt.scatter(df['followers'],df['Avg. 14 Day'],color='r',edgecolors='black')
plt.show()

# %%
plt.plot(df['followers'],'bo--')
plt.show()

# %%
channel_name=df['Channel Name'][:10]
plt.bar(channel_name,df['followers'][:10],color='green')
plt.show()
# Out:
# /tmp/ipykernel_16204/1284212586.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   channel_name=df['Channel Name'][:10]
# /tmp/ipykernel_16204/1284212586.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(channel_name,df['followers'][:10],color='green')
